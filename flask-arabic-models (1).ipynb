# %%
# !pip install flask  flask_cors  flask_ngrok

# %%
# !curl -s https://ngrok-agent.s3.amazonaws.com/ngrok.asc \
	| sudo tee /etc/apt/trusted.gpg.d/ngrok.asc >/dev/null \
	&& echo "deb https://ngrok-agent.s3.amazonaws.com buster main" \
	| sudo tee /etc/apt/sources.list.d/ngrok.list \
	&& sudo apt update \
	&& sudo apt install ngrok
# Out:
# deb https://ngrok-agent.s3.amazonaws.com buster main
# Get:1 https://ngrok-agent.s3.amazonaws.com buster InRelease [20.3 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Hit:3 https://packages.cloud.google.com/apt gcsfuse-focal InRelease
# Get:4 http://security.ubuntu.com/ubuntu focal-security InRelease [128 kB]
# Get:5 https://ngrok-agent.s3.amazonaws.com buster/main amd64 Packages [4726 B]
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 https://packages.cloud.google.com/apt cloud-sdk InRelease [1616 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1628 kB]
# Get:9 https://packages.cloud.google.com/apt google-fast-socket InRelease [5015 B]0m
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates InRelease [128 kB]
# Get:11 https://packages.cloud.google.com/apt cloud-sdk/main all Packages [1464 kB]m
# ...

# %%
# !ngrok config add-authtoken 1f2Z4sKvcb01YBjI55oR03yWXAj_43UKZ7zn3K8jnRxCpBUHw
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pip install flask pyngrok

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# %%
# %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:11:59.080291Z","iopub.execute_input":"2024-02-01T06:11:59.081215Z","iopub.status.idle":"2024-02-01T06:12:21.925467Z","shell.execute_reply.started":"2024-02-01T06:11:59.081183Z","shell.execute_reply":"2024-02-01T06:12:21.924544Z"}}
# !pip install -U transformers

# %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:12:21.927359Z","iopub.execute_input":"2024-02-01T06:12:21.927669Z","iopub.status.idle":"2024-02-01T06:12:38.123975Z","shell.execute_reply.started":"2024-02-01T06:12:21.927645Z","shell.execute_reply":"2024-02-01T06:12:38.122810Z"}}
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2  trl==0.4.7

# %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:12:38.125327Z","iopub.execute_input":"2024-02-01T06:12:38.125639Z","iopub.status.idle":"2024-02-01T06:12:54.623287Z","shell.execute_reply.started":"2024-02-01T06:12:38.125613Z","shell.execute_reply":"2024-02-01T06:12:54.622164Z"}}
# !pip install -U accelerate peft bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 16.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 12.8 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.40.2
#     Uninstalling bitsandbytes-0.40.2:
#       Successfully uninstalled bitsandbytes-0.40.2
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
#   Attempting uninstall: peft
#     Found existing installation: peft 0.4.0
#     Uninstalling peft-0.4.0:
#       Successfully uninstalled peft-0.4.0
# ...

# %%
# !pip install pyarrow==14.0.2

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM ,AutoModel ,BitsAndBytesConfig,AutoModelForSeq2SeqLM

# %%
models=[]
tokenizers=[]

# %%
        import numpy as np # linear algebra
        import pandas as pd # data processing, CSV file I/O (e.g. pd.reada_csv)
        import os

        # %% [code] {"papermill":{"duration":30.087603,"end_time":"2023-10-28T13:43:59.99579","exception":false,"start_time":"2023-10-28T13:43:29.908187","status":"completed"},"tags":[],"execution":{"iopub.status.busy":"2024-02-01T06:12:54.625584Z","iopub.execute_input":"2024-02-01T06:12:54.625904Z","iopub.status.idle":"2024-02-01T06:13:12.612428Z","shell.execute_reply.started":"2024-02-01T06:12:54.625875Z","shell.execute_reply":"2024-02-01T06:13:12.611621Z"}}
        import os
        import torch
        from transformers import (
            AutoModelForCausalLM,
            AutoTokenizer,
            BitsAndBytesConfig,
            HfArgumentParser,
            TrainingArguments,
            pipeline,
            logging,
            Trainer
        )
        from peft import LoraConfig, PeftModel
# Out:
# 2024-06-22 04:39:06.485383: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-22 04:39:06.485478: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-22 04:39:06.623348: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
peft_path=["/kaggle/input/nfaheemmarcoroni-7b-dpo-mergea-3epoch-db/results/checkpoint-1000","/kaggle/input/bigsciencebloomz-7b1-promote-same-togther/results/checkpoint-1000","/kaggle/input/mt0777/results/checkpoint-3700"]
o=0
for i in ["nfaheem/Marcoroni-7b-DPO-Merge","bigscience/bloomz-7b1","bigscience/mt0-xl"]:
        # %% [code] {"papermill":{"duration":0.73626,"end_time":"2023-10-28T13:41:22.664288","exception":false,"start_time":"2023-10-28T13:41:21.928028","status":"completed"},"tags":[],"execution":{"iopub.status.busy":"2024-02-01T06:11:58.438158Z","iopub.execute_input":"2024-02-01T06:11:58.438485Z","iopub.status.idle":"2024-02-01T06:11:58.784571Z","shell.execute_reply.started":"2024-02-01T06:11:58.438457Z","shell.execute_reply":"2024-02-01T06:11:58.783804Z"}}

        # %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:23:41.208944Z","iopub.execute_input":"2024-02-01T06:23:41.209316Z","iopub.status.idle":"2024-02-01T06:23:41.216901Z","shell.execute_reply.started":"2024-02-01T06:23:41.209285Z","shell.execute_reply":"2024-02-01T06:23:41.215906Z"}}
        # The model that you want to train from the Hugging Face hub
        # The model that you want to train from the Hugging Face hub
        model_name =i

        # The instruction dataset to use

        # Fine-tuned model name
        new_model = i
        # LoRA attention dimension
        lora_r = 16
        lora_alpha = 16

        # Dropout probability for LoRA layers
        lora_dropout = 0.05
        use_4bit = True

        # Compute dtype for 4-bit base models
        bnb_4bit_compute_dtype = "float16"

        # Quantization type (fp4 or nf4)
        bnb_4bit_quant_type = "nf4"

        use_nested_quant = False

        output_dir = "./results"

        # Number of training epochs
        num_train_epochs = 1
        fp16 = False
        bf16 = False

        per_device_train_batch_size =1

        per_device_eval_batch_size = 4

        gradient_accumulation_steps = 8

        gradient_checkpointing = True

        max_grad_norm = 0.3

        learning_rate = 5e-5

        weight_decay = 0.001

        optim = "paged_adamw_8bit"

        lr_scheduler_type = "constant"

        max_steps = -1
        warmup_ratio = 0.03
        group_by_length = True

        save_steps = 100

        logging_steps = 25

        max_seq_length = False
        packing = False
        #device_map = {"": 0}


        # %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:23:45.097414Z","iopub.execute_input":"2024-02-01T06:23:45.097815Z","iopub.status.idle":"2024-02-01T06:36:52.492210Z","shell.execute_reply.started":"2024-02-01T06:23:45.097783Z","shell.execute_reply":"2024-02-01T06:36:52.491143Z"}}
        # Load dataset (you can process it here)

        # Load tokenizer and model with QLoRA configuration
        compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

        bnb_config = BitsAndBytesConfig(
            load_in_4bit=use_4bit,
            bnb_4bit_quant_type=bnb_4bit_quant_type,
            bnb_4bit_compute_dtype=compute_dtype,
            bnb_4bit_use_double_quant=use_nested_quant,
        )

        # Check GPU compatibility with bfloat16
        if compute_dtype == torch.float16 and use_4bit:
            major, _ = torch.cuda.get_device_capability()
            if major >= 8:
                print("=" * 80)
                print("Your GPU supports bfloat16: accelerate training with bf16=True")
                print("=" * 80)

        # Load base model
        if (i=="bigscience/mt0-xl"):
             model=AutoModelForSeq2SeqLM.from_pretrained(
                    model_name,
                    quantization_config=bnb_config,
                )
            
        else:  
            model = AutoModelForCausalLM.from_pretrained(
                    model_name,
                    quantization_config=bnb_config,
                )
            
        model.config.use_cache = False
        model.config.pretraining_tp = 1

        # Load LLaMA tokenizer
        tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
        tokenizer.pad_token = tokenizer.eos_token
        tokenizer.padding_side = "right"
        peft_config = LoraConfig(
            lora_alpha=lora_alpha,
            lora_dropout=lora_dropout,
            r=lora_r,
            target_modules=['k_proj', 'gate_proj', 'v_proj', 'up_proj', 'q_proj', 'o_proj', 'down_proj'],
            bias="none",
            task_type="CAUSAL_LM",
        )

        # %% [code] {"execution":{"iopub.status.busy":"2024-01-14T16:35:42.414152Z","iopub.execute_input":"2024-01-14T16:35:42.414454Z","iopub.status.idle":"2024-01-14T16:35:54.700952Z","shell.execute_reply.started":"2024-01-14T16:35:42.414418Z","shell.execute_reply":"2024-01-14T16:35:54.699772Z"}}
        # %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:21:42.395359Z","iopub.execute_input":"2024-02-01T06:21:42.396211Z","iopub.status.idle":"2024-02-01T06:21:42.402547Z","shell.execute_reply.started":"2024-02-01T06:21:42.396178Z","shell.execute_reply":"2024-02-01T06:21:42.401598Z"}}
        peftmodel=PeftModel.from_pretrained(model,peft_path[o],is_trainable=False)

        # %% [code]
        #peftmodel.save_pretrained("bloom")


        # %% [code] {"papermill":{"duration":699.247728,"end_time":"2023-10-28T19:40:46.786544","exception":false,"start_time":"2023-10-28T19:29:07.538816","status":"completed"},"tags":[]}

        # %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:15:58.283336Z","iopub.execute_input":"2024-02-01T06:15:58.283631Z","iopub.status.idle":"2024-02-01T06:15:58.288713Z","shell.execute_reply.started":"2024-02-01T06:15:58.283606Z","shell.execute_reply":"2024-02-01T06:15:58.287788Z"}}
        tokenizer.padding_side = "left"

        # %% [code] {"execution":{"iopub.status.busy":"2024-01-04T09:51:40.662094Z","iopub.execute_input":"2024-01-04T09:51:40.662605Z","iopub.status.idle":"2024-01-04T09:51:40.930471Z","shell.execute_reply.started":"2024-01-04T09:51:40.662559Z","shell.execute_reply":"2024-01-04T09:51:40.929676Z"}}
        #tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
        #tokenizer.padding_side = "left"

        # %% [code] {"execution":{"iopub.status.busy":"2024-01-14T15:53:06.508652Z","iopub.execute_input":"2024-01-14T15:53:06.509034Z","iopub.status.idle":"2024-01-14T15:53:11.266809Z","shell.execute_reply.started":"2024-01-14T15:53:06.509003Z","shell.execute_reply":"2024-01-14T15:53:11.265803Z"}}


        # %% [code] {"execution":{"iopub.status.busy":"2024-02-01T06:15:58.289797Z","iopub.execute_input":"2024-02-01T06:15:58.290040Z","iopub.status.idle":"2024-02-01T06:15:58.338323Z","shell.execute_reply.started":"2024-02-01T06:15:58.290018Z","shell.execute_reply":"2024-02-01T06:15:58.337515Z"}}
        peftmodel.eval()
        o+=1
        # %% [code] {"execution":{"iopub.status.busy":"2024-01-14T15:35:38.661401Z","iopub.execute_input":"2024-01-14T15:35:38.661834Z","iopub.status.idle":"2024-01-14T15:36:20.504457Z","shell.execute_reply.started":"2024-01-14T15:35:38.661801Z","shell.execute_reply":"2024-01-14T15:36:20.503578Z"}}
        #peftmodel=peftmodel.merge_and_unload()
        models.append(peftmodel)
        tokenizers.append(tokenizer)
# Out:
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors.index.json:   0%|          | 0.00/22.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/487 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors:   0%|          | 0.00/14.1G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/223 [00:00<?, ?B/s]
# ...

# %%
# !pip install flask firebase_admin
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.4/317.4 kB 14.7 MB/s eta 0:00:00
# ...

# %%
from flask import Flask, render_template, request

# %%
from transformers import TextStreamer

# %%
from flask import Flask, request, render_template
from flask_cors import CORS
import json
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch.nn.functional as F
from pyngrok import ngrok
import firebase_admin
from firebase_admin import credentials, firestore

app = Flask(__name__)
CORS(app)

# Initialize Firebase Admin SDK
cred = credentials.Certificate("/kaggle/input/aaaaaaaa/emam-llms-firebase-adminsdk-5mx99-021cf33358.json")
firebase_admin.initialize_app(cred)
db = firestore.client()

# Define your tokenizer and model (assuming you have them initialized somewhere)
# tokenizer = AutoTokenizer.from_pretrained('your-model')
# peftmodel = AutoModelForSeq2SeqLM.from_pretrained('your-model')

@app.route('/', methods=['POST'])
def handle_prompt():
    # Read prompt from HTTPS request body
    data = request.get_data()
    print(f"Generating an image of {data}")
    data = json.loads(data)

    context = data['context'].lower()  # Get the input data from the user
    quetion = data['quetion'].lower()
    answer = data['answer'].lower()
    generate= data['generate']
    ids=data['id']
    if ids>-1:
        def chat_Format(context, quetion, answer,ids):
                       if (ids!=2): 
                        return "Instruction:/n check answer is true or false of next quetion using context below:\n" + "#context: " + context + f".\n#quetion: " + quetion + f".\n#student answer: " + answer + ".\n#response:"
                       else:
                            return      "Instruction:/n check answer is true or false of next quetion using context below:\n" + "#Context: " + context + f".\n#Quetion: " + quetion + f".\n#Student answer: " + answer + ".\n#Response:"

        inp2 = chat_Format(context, quetion, answer,ids)
        w = tokenizers[ids](inp2, add_special_tokens=True,
                      pad_to_max_length=True,
                      return_attention_mask=True,
                      return_tensors='pt')
        response=""
        if(generate):
            outputs = tokenizers[ids].batch_decode(models[ids].generate(input_ids=w['input_ids'].cuda(), attention_mask=w['attention_mask'].cuda(), max_new_tokens=data['max_new_tokens'], num_beams=data['num_beams'], do_sample=data['do_sample'], num_return_sequences=1), skip_special_tokens=True)
            response = outputs
            
        print("response123123",response)
        s = models[ids](input_ids=w['input_ids'].cuda(), attention_mask=w['attention_mask'].cuda())['logits'][0][-1]
        s = F.softmax(s, dim=-1)
        yes_token_id = tokenizers[ids].convert_tokens_to_ids("True")
        no_token_id = tokenizers[ids].convert_tokens_to_ids("False")
        for i in  ["Yes", "yes", "True", "true","صحيح","نعم"]:
            s[yes_token_id] += s[tokenizers[ids].convert_tokens_to_ids(i)]
        for i in ["No", "no", "False", "false","خطأ","خطا","لا"]:
            s[no_token_id] += s[tokenizers[ids].convert_tokens_to_ids(i)]
        true = (s[yes_token_id] / (s[no_token_id] + s[yes_token_id])).item()
        print(s[yes_token_id])
        s = s**.5
        true2 = (s[yes_token_id] / (s[yes_token_id] + s[no_token_id])).item()
        # Decode the response
        print((response, true, true2))
        return {"response": response, "true": true, "true2": true2}

    else:
        true2=0
        true=0
        for ids in range(len(models)) :
                        def chat_Format(context, quetion, answer,ids):
                           if (ids!=2): 
                            return "Instruction:/n check answer is true or false of next quetion using context below:\n" + "#context: " + context + f".\n#quetion: " + quetion + f".\n#student answer: " + answer + ".\n#response:"
                           else:
                                return      "Instruction:/n check answer is true or false of next quetion using context below:\n" + "#Context: " + context + f".\n#Quetion: " + quetion + f".\n#Student answer: " + answer + ".\n#Response:"

                        inp2 = chat_Format(context, quetion, answer,ids)
                        streamer = TextStreamer(tokenizers[ids], skip_prompt=True, skip_special_tokens=True)

                        w = tokenizers[ids](inp2, add_special_tokens=True,
                                      pad_to_max_length=True,
                                      return_attention_mask=True,
                                      return_tensors='pt')

                        response=""
                        if(generate):
                            outputs = tokenizers[ids].batch_decode(models[ids].generate(input_ids=w['input_ids'].cuda(), attention_mask=w['attention_mask'].cuda(), max_new_tokens=data['max_new_tokens'], num_beams=data['num_beams'], do_sample=data['do_sample'], num_return_sequences=1), skip_special_tokens=True)
                            response = outputs
                        s = models[ids](input_ids=w['input_ids'].cuda(), attention_mask=w['attention_mask'].cuda())['logits'][0][-1]
                        s = F.softmax(s, dim=-1)
                        yes_token_id = tokenizers[ids].convert_tokens_to_ids("True")
                        no_token_id = tokenizers[ids].convert_tokens_to_ids("False")
                        for i in ["Yes", "yes", "True", "true","صحيح"]:
                            s[yes_token_id] += s[tokenizers[ids].convert_tokens_to_ids(i)]
                        for i in ["No", "no", "False", "false","خطأ"]:
                            s[no_token_id] += s[tokenizers[ids].convert_tokens_to_ids(i)]
                        true += (s[yes_token_id] / (s[no_token_id] + s[yes_token_id])).item()
                        print(s[yes_token_id])
                        s = s**.5
                        true2 += (s[yes_token_id] / (s[yes_token_id] + s[no_token_id])).item()
                        # Decode the response
                        print((response, true, true2))
    return {"response": response, "true": true/len(models), "true2": true2/len(models)}

if __name__ == '__main__':
    # Start ngrok tunnel
    ngrok_tunnel = ngrok.connect(5000)
    public_url = ngrok_tunnel.public_url
    print('Public URL:', public_url)
    
    # Save ngrok URL to Firestore
    db.collection('ngrok').document('tunnel').set({'url_1': public_url})
    
    app.run()
# Out:
# ERROR:  authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.
# ERROR:  You can run multiple tunnels on a single agent session using a configuration file.
# ERROR:  To learn more, see https://ngrok.com/docs/secure-tunnels/ngrok-agent/reference/config/
# ERROR:  You can view your current agent sessions in the dashboard:
# ERROR:  https://dashboard.ngrok.com/tunnels/agents
# ERROR:
# ERROR:  ERR_NGROK_108
# ERROR:
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# Cell In[15], line 108
#     104     return {"response": response, "true": true/len(models), "true2": true2/len(models)}
#     106 if __name__ == '__main__':
#     107     # Start ngrok tunnel
# --> 108     ngrok_tunnel = ngrok.connect(5000)
#     109     public_url = ngrok_tunnel.public_url
#     110     print('Public URL:', public_url)
#
# ...
